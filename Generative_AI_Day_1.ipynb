# %%
a = 90
a
# Out:
# 90

# %% [markdown]
# <h1>Generative AI</h1>

# %%
#valiables
#data types
'''
int
string
float
boolean
'''
#typecasting
# Out:
# '\nint\nstring\nfloat\nboolean\n'

# %%
a = 90
b  = str(a)
b
type(b)
# Out:
# str

# %%
a = 90
b  = float(a)
b
# type(b)
# Out:
# 90.0

# %%
a = "hello"
b  = float(a)
b
type(b)

# %%
a = input("Enter the value of a : ")
a
# Out:
# Enter the value of a :  90
# '90'

# %%
a = 90
if a>100:
    print("your value you big")
else:
    print("your value you small")
# Out:
# your value you small

# %%
# if
# if else
# elif
# nested if

# %%
# for loop
# nested for loop
# while loop
# nested while loop

# %%
for i in range(5):
    i=i+1
    print(i,end="")
# Out:
# 12345

# %%
for i in range(5):
    for j in range(5):
        print("*",end=" ")
    print()
# Out:
# * * * * *
# * * * * *
# * * * * *
# * * * * *
# * * * * *

# %%
i=0
while True:
    print("*")
    i+=1
    if i>5:
        break
# Out:
# *
# *
# *
# *
# *
# *

# %%
# data structure
'''
ducplication
homo/hit
curd

1 list
2 tuple
3 dictionary
4 set
'''

# %%
a = [1,2,3,4,5,6]
a[2] = 90
a
# Out:
# [1, 2, 90, 4, 5, 6]

# %%
# help(a)
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
for i in dir(a):
    if '_'not in i:
        print(i)
# Out:
# append
# clear
# copy
# count
# extend
# index
# insert
# pop
# remove
# reverse
# sort

# %%
b = [2,1,3,5,6]
# print(b.reverse())
# help(b.reverse)
# help(b.sort)
b.sort(reverse=True)
b
# Out:
# [6, 5, 3, 2, 1]

# %%
a = {}
type(a)
# Out:
# dict

# %%
# a = {"key":"value"}
a = {"email":"user1@gamil.com"}
a['email']
# Out:
# 'user1@gamil.com'

# %%
# a = {"key":"value"}
a = {"email":"user1@gamil.com",
    "password":"pass@123"}
a['email']
a['password']
# Out:
# 'pass@123'

# %%
# a = {"key":"value"}
a = [
    {"email":"user1@gamil.com","password":"pass@123"},
    {"email":"user1@gamil.com","password":"pass@123"},
    {"email":"user3a@gamil.com","password":"pass@123"},
    {"email":"user1@gamil.com","password":"pass@123"},
    {"email":"user1@gamil.com","password":"pass@123"},
        ]
a[2]['email'],['password']
# a[2]['email','password']
# Out:
# ('user3a@gamil.com', ['password'])

# %%
products = [
    {
        "cate1":
            [
                "product1",
                "product2",
                "product3",
                "product4",
            ]
                
    },
    {
        "cate2":
            [
                "product1",
                "product2",
                "product3",
                "product4",
            ]
                
    }
]
products[0]["cate1"][3]
# Out:
# 'product4'

# %%
products = [
    {
        "cate1":
            [
               {
                   "pro1":{
                       "name":"remote",
                       "qty":90,
                       "price":1000
                   }
                           
               }
            ]
                
    }
]
# products[0]["cate1"][0]["pro1"]["price"]
data = products[0]["cate1"]
product = data[0]
product["pro1"]["price"]
# Out:
# 1000
